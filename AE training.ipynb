# %%
# %load_ext autoreload
# %autoreload 2

# %%
import time
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
from torch import nn
from torch.utils.data import DataLoader
import pytorch_lightning as pl

from src.autoencoder import AutoEncoder
from src.utils import *
from src.rtd import RTDLoss, MinMaxRTDLoss
from src.top_ae import TopologicallyRegularizedAutoencoder

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

from collections import defaultdict

from tqdm.notebook import tqdm

# %%
config = {
    "dataset_name":"COIL-20",
    "version":"d16",
    "model_name":"default",
    "max_epochs":2,
    "gpus":[0],
    "rtd_every_n_batches":1,
    "rtd_start_epoch":0,
    "rtd_l":1.0, # rtd loss 
    "n_runs":1, # number of runs for each model
    "card":50, # number of points on the persistence diagram
    "n_threads":50, # number of threads for parallel ripser computation of pers homology
    "latent_dim":16, # latent dimension (2 or 3 for vizualization purposes)
    "input_dim":128*128,
    "n_hidden_layers":3,
    "hidden_dim":512,
    "batch_size":256,
#     "width":80,
#     "heigth":80,
    "engine":"ripser",
    "is_sym":True,
    "lr":5e-4
#     'mode':'minimum',
#     'lp':1.0
}

# %%
def get_model(input_dim, latent_dim=2, n_hidden_layers=2, m_type='encoder', **kwargs):
    n = int(np.log2(input_dim))-1
    layers = []
    if m_type == 'encoder':
        in_dim = input_dim
        if input_dim  // 2 >= latent_dim:
            out_dim = input_dim // 2
        else:
            out_dim = input_dim
        for i in range(min(n, n_hidden_layers)):
            layers.extend([nn.Linear(in_dim, out_dim), nn.ReLU()])
            in_dim = out_dim
            if in_dim  // 2 >= latent_dim:
                out_dim = in_dim // 2
            else:
                out_dim = in_dim
        layers.extend([nn.Linear(in_dim, latent_dim)])
    elif m_type == 'decoder':
        in_dim = latent_dim
        out_dim = latent_dim * 2
        for i in range(min(n, n_hidden_layers)):
            layers.extend([nn.Linear(in_dim, out_dim), nn.ReLU()])
            in_dim = out_dim
            out_dim *= 2
        layers.extend([nn.Linear(in_dim, input_dim)])
    return nn.Sequential(*layers)

def get_list_of_models(**config):
    # define a list of models
    encoder = get_linear_model(
        m_type='encoder',
        **config
    )
    decoder = get_linear_model(
        m_type='decoder',
        **config
    )
    models = {
        'Basic AutoEncoder':AutoEncoder(
           encoder = encoder,
            decoder = decoder,
            MSELoss = nn.MSELoss(),
            **config
        ),
        'Topological AutoEncoder':TopologicallyRegularizedAutoencoder(
            encoder = encoder,
            decoder = decoder,
            MSELoss = nn.MSELoss(),
            **config
        ),
        'RTD AutoEncoder H1':AutoEncoder(
            encoder = encoder,
            decoder = decoder,
            RTDLoss = RTDLoss(dim=1, lp=1.0,  **config), # only H1
            MSELoss = nn.MSELoss(),
            **config
        )
    }
    return models, encoder, decoder

# %%
def collate_with_matrix(samples):
    indicies, data, labels = zip(*samples)
    data, labels = torch.tensor(np.asarray(data)), torch.tensor(np.asarray(labels))
    if len(data.shape) > 2:
        dist_data = torch.flatten(data, start_dim=1)
    else:
        dist_data = data
    x_dist = torch.cdist(dist_data, dist_data, p=2) / np.sqrt(dist_data.shape[1])
#     x_dist = (x_dist + x_dist.T) / 2.0 # make symmetrical (cdist is prone to computational errors)
    return data, x_dist, labels

def collate_with_matrix_geodesic(samples):
    indicies, data, labels, dist_data = zip(*samples)
    data, labels = torch.tensor(np.asarray(data)), torch.tensor(np.asarray(labels))
    x_dist = torch.tensor(np.asarray(dist_data)[:, indicies])
    return data, x_dist, labels

# %%
dataset_name = config['dataset_name']
train_data = np.load(f'data/{dataset_name}/prepared/train_data.npy').astype(np.float32)

try:
    test_data = np.load(f'data/{dataset_name}/prepared/test_data.npy').astype(np.float32)
except FileNotFoundError:
    ids = np.random.choice(np.arange(len(train_data)), size=int(0.2*len(train_data)), replace=False)
    test_data = train_data[ids]

try:
    train_labels = np.load(f'data/{dataset_name}/prepared/train_labels.npy')
except FileNotFoundError:
    train_labels = None

try:
    test_labels = np.load(f'data/{dataset_name}/prepared/test_labels.npy')
except FileNotFoundError:
    if train_labels is None:
        test_labels = None
    else:
        test_labels = train_labels[ids]

# %%
scaler = FurthestScaler()
# scaler = None
flatten = True
geodesic = False

train = FromNumpyDataset(
    train_data, 
    train_labels, 
    geodesic=geodesic, 
    scaler=scaler, 
    flatten=flatten, 
    n_neighbors=2
)
print("Train done")
test = FromNumpyDataset(
    test_data, 
    test_labels, 
    geodesic=geodesic, 
    scaler = train.scaler,    
    flatten=flatten, 
    n_neighbors=2
)

train_loader = DataLoader(
    train, 
    batch_size=config["batch_size"], 
    num_workers=2, 
    collate_fn=collate_with_matrix_geodesic if geodesic else collate_with_matrix, 
    shuffle=True
)

val_loader = DataLoader(
    test,
    batch_size=config["batch_size"],
    num_workers=2,
    collate_fn=collate_with_matrix_geodesic if geodesic else collate_with_matrix,
)
# Out:
# Train done

# %%
def train_autoencoder(model, train_loader, val_loader=None, model_name='default', 
                      dataset_name='MNIST', gpus=[3], max_epochs=100, run=0, version=""):
    version = f"{dataset_name}_{model_name}_{version}_{run}"
    logger = pl.loggers.TensorBoardLogger(save_dir=os.getcwd(), name='lightning_logs', version=version)
    trainer = pl.Trainer(
        logger=logger, 
        devices=gpus, 
        max_epochs=max_epochs, 
        log_every_n_steps=1, 
        num_sanity_val_steps=0
    )
    trainer.fit(model, train_loader, val_loader)
    return model

def dump_figures(figures, dataset_name, version):
    for model_name in figures:
        figures[model_name].savefig(f'results/{dataset_name}/{model_name}_{version}.png')

def train_models(train_loader, val_loader, dataset_name="", max_epochs=1, gpus=[], n_neighbors=[1], n_runs=1, version='', **kwargs):
    models, encoder, decoder = get_list_of_models(**kwargs)
    for model_name in tqdm(models, desc=f"Training models"):
        if 'AutoEncoder' in model_name: # train an autoencoder
            models[model_name] = train_autoencoder(
                models[model_name], 
                train_loader, 
                val_loader, 
                model_name, 
                dataset_name,
                gpus,
                max_epochs,
                0,
                version
            )
        else: # umap / pca / t-sne (sklearn interface)
            train_latent = models[model_name].fit_transform(train_loader.dataset.data)
        # measure training time
    return encoder, decoder, models

# %%
encoder, decoder, trained_models = train_models(train_loader, val_loader, **config)
# Out:
# Using python to compute signatures
# Training models:   0%|          | 0/3 [00:00<?, ?it/s]
# /users/eleves-b/2021/pierre.aguie/.local/lib/python3.9/site-packages/lightning_fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /users/eleves-b/2021/pierre.aguie/.local/lib/python3 ...
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA RTX A2000 12GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# /users/eleves-b/2021/pierre.aguie/.local/lib/python3.9/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:654: Checkpoint directory /users/eleves-b/2021/pierre.aguie/RTD_AE/lightning_logs/COIL-20_Basic AutoEncoder_d16_0/checkpoints exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name         | Type       | Params | Mode
# ----------------------------------------------------
# 0 | encoder      | Sequential | 9.2 M  | train
# 1 | decoder      | Sequential | 9.2 M  | train
# 2 | MSELoss      | MSELoss    | 0      | train
#   | other params | n/a        | 1      | n/a
# ----------------------------------------------------
# 18.4 M    Trainable params
# 0         Non-trainable params
# 18.4 M    Total params
# 73.548    Total estimated model params size (MB)
# 21        Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=2` reached.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /users/eleves-b/2021/pierre.aguie/.local/lib/python3.9/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:654: Checkpoint directory /users/eleves-b/2021/pierre.aguie/RTD_AE/lightning_logs/COIL-20_Topological AutoEncoder_d16_0/checkpoints exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name         | Type                         | Params | Mode
# ----------------------------------------------------------------------
# 0 | encoder      | Sequential                   | 9.2 M  | train
# 1 | decoder      | Sequential                   | 9.2 M  | train
# 2 | MSELoss      | MSELoss                      | 0      | train
# 3 | topo_sig     | TopologicalSignatureDistance | 0      | train
#   | other params | n/a                          | 1      | n/a
# ----------------------------------------------------------------------
# 18.4 M    Trainable params
# 0         Non-trainable params
# 18.4 M    Total params
# 73.548    Total estimated model params size (MB)
# 22        Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=2` reached.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name         | Type       | Params | Mode
# ----------------------------------------------------
# 0 | encoder      | Sequential | 9.2 M  | train
# 1 | decoder      | Sequential | 9.2 M  | train
# 2 | RTDLoss      | RTDLoss    | 0      | train
# 3 | MSELoss      | MSELoss    | 0      | train
#   | other params | n/a        | 1      | n/a
# ----------------------------------------------------
# 18.4 M    Trainable params
# 0         Non-trainable params
# 18.4 M    Total params
# 73.548    Total estimated model params size (MB)
# 23        Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# {'dgms': {0: array([(0., 8.52992252e-06), (0., 9.34406216e-06), (0., 1.00927400e-05),
#        (0., 1.26519199e-05), (0., 1.37540865e-05), (0., 1.51391105e-05),
#        (0., 1.52587891e-05), (0., 1.52587891e-05), (0., 1.52587891e-05),
#        (0., 1.52587891e-05), (0., 1.52587891e-05), (0., 1.64076337e-05),
#        (0., 1.71661377e-05), (0., 1.75848854e-05), (0., 1.75848854e-05),
#        (0., 1.83938046e-05), (0., 1.90734863e-05), (0., 2.04540356e-05),
#        (0., 2.15791861e-05), (0., 2.15791861e-05), (0., 2.15791861e-05),
#        (0., 2.15791861e-05), (0., 2.15791861e-05), (0., 2.15791861e-05),
#        (0., 2.15791861e-05), (0., 2.15791861e-05), (0., 2.15791861e-05),
#        (0., 2.17471206e-05), (0., 2.64289974e-05), (0., 2.64289974e-05),
#        (0., 2.64289974e-05), (0., 2.91768229e-05), (0., 3.05175781e-05),
#        (0., 3.05175781e-05), (0., 3.05175781e-05), (0., 3.05175781e-05),
292]), array([325, 292])], [array([243]), array([499, 243])], [array([237]), array([493, 237])], [array([236]), array([492, 236])], [array([202]), array([458, 202])], [array([194]), array([450, 194])], [array([177]), array([433, 177])], [array([157]), array([413, 157])], [array([156]), array([412, 156])], [array([126]), array([382, 126])], [array([120]), array([376, 120])], [array([83]), array([339,  83])], [array([77]), array([333,  77])], [array([73]), array([329,  73])], [array([39]), array([295,  39])], [array([19]), array([275,  19])], [array([266]), array([452, 266])], [array([432]), array([470, 432])], [array([74]), array([330,  74])], [array([56]), array([312,  56])], [array([7]), array([263,   7])], [array([422]), array([437, 422])], [array([322]), array([503, 322])], [array([377]), array([449, 377])], [array([242]), array([498, 242])], [array([205]), array([461, 205])], [array([192]), array([448, 192])], [array([191]), array([447, 191])], [array([175]), array([431, 175])], [array([167]), array([423, 167])], [array([166]), array([422, 166])], [array([124]), array([380, 124])], [array([37]), array([293,  37])], [array([24]), array([280,  24])], [array([3]), array([259,   3])], [array([254]), array([510, 254])], [array([252]), array([508, 252])], [array([161]), array([417, 161])], [array([32]), array([288,  32])], [array([10]), array([266,  10])], [array([280]), array([356, 280])], [array([267]), array([351, 267])], [array([210]), array([466, 210])], [array([82]), array([338,  82])], [array([356]), array([451, 356])], [array([146]), array([402, 146])], [array([133]), array([389, 133])], [array([80]), array([336,  80])], [array([264]), array([455, 264])]], 1: [[array([344, 494]), array([344, 464, 494])], [array([269, 293]), array([275, 293, 381])], [array([423, 466]), array([423, 432, 466])], [array([401, 440]), array([401, 417, 440])], [array([285, 346]), array([285, 346, 442])], [array([313, 396]), array([313, 396, 409])], [array([450, 509]), array([441, 450, 509])], [array([273, 377]), array([273, 377, 441])], [array([321, 475]), array([425, 453, 464])], [array([293, 381]), array([293, 370, 381])], [array([301, 385]), array([ 14,  45, 301])], [array([273, 291]), array([273, 291, 487])], [array([380, 499]), array([380, 416, 499])], [array([302, 342]), array([302, 342, 441])], [array([302, 309]), array([302, 309, 321])], [array([381, 450]), array([381, 417, 450])], [array([329, 492]), array([329, 402, 468])], [array([290, 510]), array([290, 432, 510])], [array([355, 447]), array([288, 355, 447])], [array([341, 385]), array([260, 341, 385])], [array([342, 462]), array([426, 441, 462])], [array([441, 464]), array([441, 464, 479])], [array([325, 464]), array([416, 464, 468])], [array([461, 510]), array([432, 461, 510])], [array([432, 496]), array([290, 302, 496])], [array([293, 479]), array([29 ...
# {'dgms': {0: array([(0., 2.6973983e-06), (0., 2.6973983e-06), (0., 2.6973983e-06),
#        (0., 2.6973983e-06), (0., 2.6973983e-06), (0., 2.6973983e-06),
#        (0., 2.6973983e-06), (0., 2.6973983e-06), (0., 2.6973983e-06),
#        (0., 2.6973983e-06), (0., 2.6973983e-06), (0., 2.6973983e-06),
#        (0., 2.6973983e-06), (0., 2.6973983e-06), (0., 2.6973983e-06),
#        (0., 2.6973983e-06), (0., 2.6973983e-06), (0., 2.6973983e-06),
#        (0., 2.6973983e-06), (0., 2.6973983e-06), (0., 2.6973983e-06),
#        (0., 2.6973983e-06), (0., 2.6973983e-06), (0., 2.6973983e-06),
#        (0., 2.6973983e-06), (0., 2.6973983e-06), (0., 2.6973983e-06),
#        (0., 2.6973983e-06), (0., 2.6973983e-06), (0., 2.6973983e-06),
#        (0., 2.6973983e-06), (0., 2.6973983e-06), (0., 2.6973983e-06),
#        (0., 2.6973983e-06), (0., 2.6973983e-06), (0., 2.6973983e-06),
#        (0., 2.6973983e-06), (0., 2.6973983e-06), (0., 2.6973983e-06),
#        (0., 2.6973983e-06), (0., 2.6973983e-06), (0., 2.6973983e-06),
#        (0., 2.6973983e-06), (0., 2.6973983e-06), (0., 2.6973983e-06),
#        (0., 2.6973983e-06), (0., 2.6973983e-06), (0., 3.8146973e-06),
#        (0., 3.8146973e-06), (0., 3.8146973e-06), (0., 3.8146973e-06),
#        (0., 3.8146973e-06), (0., 3.8146973e-06), (0., 3.8146973e-06),
#        (0., 3.8146973e-06), (0., 3.8146973e-06), (0., 3.8146973e-06),
#        (0., 3.8146973e-06), (0., 3.8146973e-06), (0., 3.8146973e-06),
#        (0., 3.8146973e-06), (0., 3.8146973e-06), (0., 4.6720311e-06)],
#       dtype=[('birth', '<f4'), ('death', '<f4')]), 1: array([], dtype=float64)}, 'pairs': {0: [[array([247]), array([503, 247])], [array([239]), array([495, 239])], [array([232]), array([488, 232])], [array([218]), array([474, 218])], [array([216]), array([472, 216])], [array([213]), array([469, 213])], [array([209]), array([465, 209])], [array([208]), array([464, 208])], [array([207]), array([463, 207])], [array([197]), array([453, 197])], [array([196]), array([452, 196])], [array([192]), array([448, 192])], [array([188]), array([444, 188])], [array([185]), array([441, 185])], [array([158]), array([414, 158])], [array([155]), array([411, 155])], [array([149]), array([405, 149])], [array([143]), array([399, 143])], [array([142]), array([398, 142])], [array([141]), array([397, 141])], [array([136]), array([392, 136])], [array([134]), array([390, 134])], [array([125]), array([381, 125])], [array([123]), array([379, 123])], [array([122]), array([378, 122])], [array([118]), array([374, 118])], [array([114]), array([370, 114])], [array([113]), array([369, 113])], [array([109]), array([365, 109])], [array([102]), array([358, 102])], [array([100]), array([356, 100])], [array([97]), array([353,  97])], [array([84]), array([340,  84])], [array([79]), array([335,  79])], [array([74]), array([330,  74])], [array([69]), array([325,  69])], [array([56]), array([312,  56])], [array([46]), array([302,  46])], [array([40]), array([296,  40])], [array([38]), array([294,  38])], [array([36]), array([292,  36])], [array([24]), array([280,  24])], [array([23]), array([279,  23])], [array([17]), array([273,  17])], [array([16]), array([272,  16])], [array([14]), array([270,  14])], [array([13]), array([269,  13])], [array([251]), array([507, 251])], [array([241]), array([497, 241])], [array([174]), array([430, 174])], [array([168]), array([424, 168])], [array([130]), array([386, 130])], [array([112]), array([368, 112])], [array([99]), array([355,  99])], [array([89]), array([345,  89])], [array([87]), array([343,  87])], [array([86]), array([342,  86])], [array([83]), array([339,  83])], [array([68]), array([324,  68])], [array([59]), array([315,  59])], [array([50]), array([306,  50])], [array([26]), array([282,  26])], [array([224]), array([480, 224])]], 1: []}}
# {'dgms': {0: array([(0., 1.5258789e-05), (0., 1.5258789e-05), (0., 1.5258789e-05),
#        (0., 1.5258789e-05), (0., 1.5258789e-05), (0., 1.5258789e-05),
#        (0., 1.5258789e-05), (0., 1.5258789e-05), (0., 2.1579186e-05),
#        (0., 2.1579186e-05), (0., 2.1579186e-05), (0., 2.1579186e-05),
#        (0., 2.1579186e-05), (0., 2.1579186e-05), (0., 2.1579186e-05),
#        (0., 2.1579186e-05), (0., 2.1579186e-05), (0., 2.1579186e-05),
#        (0., 2.1579186e-05), (0., 2.6428997e-05), (0., 2.6428997e-05),
#        (0., 3.0517578e-05), (0., 3.0517578e-05), (0., 3.0517578e-05),
#        (0., 3.0517578e-05), (0., 3.0517578e-05), (0., 3.0517578e-05),
#        (0., 3.0517578e-05), (0., 3.0517578e-05), (0., 3.0517578e-05),
#        (0., 3.0517578e-05), (0., 3.0517578e-05), (0., 3.0517578e-05),
#        (0., 3.0517578e-05), (0., 3.0517578e-05), (0., 3.0517578e-05),
#        (0., 3.0517578e-05), (0., 3.0517578e-05), (0., 3.0517578e-05),
#        (0., 3.0517578e-05), (0., 3.0517578e-05), (0., 3.0517578e-05),
#        (0., 3.0517578e-05), (0., 3.0517578e-05), (0., 3.0517578e-05),
#        (2.73119309e-04, 0.02117485), (2.72251258e-04, 0.02653164),
#        (2.69745127e-04, 0.03331906), (2.68330652e-04, 0.01924643),
#        (2.65588838e-04, 0.03631979), (2.61957932e-04, 0.02682609),
#        (2.60382338e-04, 0.03644622), (2.59731198e-04, 0.02246164),
#        (2.57449836e-04, 0.03107039), (2.56095431e-04, 0.03274404),
#        (2.54010898e-04, 0.03107163), (2.54003739e-04, 0.03283336),
#        (2.53910519e-04, 0.02612316), (2.48583965e-04, 0.0305979 ),
#        (2.47320917e-04, 0.02305681), (2.45406729e-04, 0.02479508),
#        (2.43978036e-04, 0.00025905), (2.40566005e-04, 0.02174311),
#        (2.39207366e-04, 0.02432008), (2.39161687e-04, 0.02184421),
#        (2.32388993e-04, 0.03234186), (2.31619881e-04, 0.03312934),
#        (2.28358127e-04, 0.0222283 ), (2.27959128e-04, 0.01686148),
#        (2.27062774e-04, 0.02371302), (2.26974546e-04, 0.01204165),
#        (2.23359923e-04, 0.02130996), (2.23009120e-04, 0.02149239),
#        (2.19013484e-04, 0.02057299), (2.18805551e-04, 0.02409878),
#        (2.15864944e-04, 0.02563277), (2.15738371e-04, 0.01860927),
#        (2.14409229e-04, 0.03083375), (2.12335624e-04, 0.02162196),
#        (2.11708713e-04, 0.03280613), (2.11459148e-04, 0.02391058),
#        (2.11329942e-04, 0.01702263), (2.11209292e-04, 0.02775758),
#        (2.10137601e-04, 0.01161317), (2.06818790e-04, 0.00024803),
#        (2.05635690e-04, 0.02027245), (2.04472468e-04, 0.02614669),
#        (2.01530522e-04, 0.02360523), (2.00334383e-04, 0.02571065),
#        (2.00134324e-04, 0.00021472), (1.98884009e-04, 0.03497447),
#        (1.94963650e-04, 0.02318449), (1.92784792e-04, 0.02581639),
#        (1.92311985e-04, 0.02978115), (1.92198335e-04, 0.0210304 ),
#        (1.91400904e-04, 0.01766452), (1.91381871e-04, 0.0201814 ),
#        (1.91096246e-04, 0.01343772), (1.88341815e-04, 0.02860411),
#        (1.86769117e-04, 0.02714153), (1.84749937e-04, 0.0129944 ),
#        (1.81598894e-04, 0.02490566), (1.81398253e-04, 0.02773883),
#        (1.80744639e-04, 0.0269649 ), (1.80623712e-04, 0.03081659),
#        (1.78942500e-04, 0.02640843), (1.76545436e-04, 0.02607708),
#        (1.76421643e-04, 0.02931392), (1.73024382e-04, 0.02496942),
#        (1.71119696e-04, 0.02216397), (1.70682892e-04, 0.02740992),
#        (1.67745340e-04, 0.02480306), (1.65351114e-04, 0.01805697),
#        (1.62698037e-04, 0.02690901), (1.60897485e-04, 0.02658896),
#        (1.59989606e-04, 0.01433592), (1.59179530e-04, 0.02800894),
#        (1.58307797e-04, 0.02738775), (1.58307797e-04, 0.00644261),
#        (1.56631198e-04, 0.01762659), (1.55616552e-04, 0.02976563),
#        (1.55323767e-04, 0.01872039), (1.55112619e-04, 0.02354842),
#        (1.54959940e-04, 0.01852519), (1.53056491e-04, 0.01849287),
#        (1.48430336e-04, 0.01429692), (1.47037645e-04, 0.01255137),
[array([75]), array([331,  75])], [array([67]), array([323,  67])], [array([64]), array([320,  64])], [array([62]), array([318,  62])], [array([57]), array([313,  57])], [array([50]), array([306,  50])], [array([32]), array([288,  32])], [array([18]), array([274,  18])], [array([363]), array([504, 363])], [array([343]), array([468, 343])], [array([215]), array([471, 215])], [array([35]), array([291,  35])], [array([393]), array([460, 393])], [array([240]), array([496, 240])], [array([236]), array([492, 236])], [array([160]), array([416, 160])], [array([153]), array([409, 153])], [array([73]), array([329,  73])], [array([58]), array([314,  58])], [array([253]), array([509, 253])], [array([83]), array([339,  83])], [array([28]), array([284,  28])], [array([53]), array([309,  53])], [array([17]), array([273,  17])], [array([16]), array([272,  16])]], 1: [[array([395, 488]), array([395, 452, 488])], [array([387, 417]), array([326, 387, 394])], [array([258, 283]), array([283, 341, 348])], [array([387, 394]), array([265, 326, 387])], [array([395, 452]), array([395, 414, 490])], [array([260, 436]), array([265, 436, 451])], [array([265, 422]), array([131, 227, 428])], [array([297, 334]), array([297, 334, 480])], [array([395, 442]), array([139, 191, 442])], [array([341, 385]), array([265, 385, 500])], [array([377, 403]), array([298, 377, 506])], [array([265, 341]), array([  2, 214, 348])], [array([266, 445]), array([266, 297, 445])], [array([348, 373]), array([301, 348, 493])], [array([373, 477]), array([373, 477, 493])], [array([347, 440]), array([347, 409, 440])], [array([304, 317]), array([301, 304, 457])], [array([267, 312]), array( ...
# {'dgms': {0: array([(0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 2.6987334e-06), (0., 2.6987334e-06),
#        (0., 2.6987334e-06), (0., 3.8165854e-06), (0., 3.8165854e-06),
#        (0., 3.8165854e-06), (0., 3.8165854e-06), (0., 3.8165854e-06),
#        (0., 3.8165854e-06), (0., 3.8165854e-06)],
# ...
#        (0.00744132, 0.01958545), (0.00742586, 0.01759195),
#        (0.00732981, 0.0246176 ), (0.00726068, 0.02079863),
#        (0.00718664, 0.0174639 ), (0.00716822, 0.01525462),
#        (0.0071655 , 0.02196186), (0.00715169, 0.02101604),
#        (0.0070975 , 0.01953621), (0.00705706, 0.0251129 ),
#        (0.0070311 , 0.01652883), (0.00678149, 0.03231163),
#        (0.00673118, 0.02045859), (0.00669243, 0.02583309),
#        (0.00668177, 0.02438959), (0.00667463, 0.01299949),
#        (0.00650582, 0.0181769 ), (0.0064372 , 0.02179825),
#        (0.0064008 , 0.01913082), (0.00633763, 0.02549016),
#        (0.00632717, 0.0066734 ), (0.00625768, 0.0242184 ),
#        (0.00622506, 0.02430625), (0.00598857, 0.02457854),
#        (0.00592679, 0.01859395), (0.00590231, 0.02222061),
#        (0.0058986 , 0.0137549 ), (0.00587247, 0.0074444 ),
#        (0.00586317, 0.01561096), (0.00584631, 0.01341118),
#        (0.00581183, 0.02194614), (0.00567205, 0.0232816 ),
#        (0.00565022, 0.01562114), (0.00564692, 0.01886554),
#        (0.00561928, 0.01898468), (0.00540799, 0.01189829),
#        (0.00533542, 0.00618429), (0.00532514, 0.00540699),
#        (0.0052862 , 0.00867483), (0.00518267, 0.01357212),
#        (0.00514214, 0.01746066), (0.00511224, 0.02108312),
#        (0.00511093, 0.01395565), (0.0050587 , 0.01454712),
#        (0.00487547, 0.01947974), (0.00486681, 0.02466769),
#        (0.00480644, 0.01818206), (0.00479196, 0.02156324),
#        (0.00476186, 0.01084418), (0.00474583, 0.0084483 ),
#        (0.00474217, 0.01434284), (0.00465355, 0.01317547),
#        (0.00464594, 0.01407645), (0.00462632, 0.02071777),
#        (0.00457199, 0.01092845), (0.00455149, 0.01708158),
#        (0.00445335, 0.01369821), (0.00435083, 0.02397835),
#        (0.00429069, 0.01790086), (0.00428699, 0.01981903),
#        (0.00419666, 0.01382793), (0.00415783, 0.02051683),
#        (0.0041543 , 0.01728288), (0.00409156, 0.01096193),
#        (0.00399389, 0.01571557), (0.00395712, 0.0081167 ),
#        (0.00385717, 0.0132059 ), (0.00381247, 0.01999732),
#        (0.00378244, 0.01398382), (0.0036902 , 0.01053356),
#        (0.00362906, 0.01763307), (0.00351228, 0.01589898),
#        (0.00350849, 0.0077777 ), (0.00350796, 0.00947299),
#        (0.00348032, 0.01302074), (0.00339641, 0.01703918),
#        (0.00330892, 0.01557996), (0.00303592, 0.01582675),
#        (0.00292972, 0.01041598), (0.002701  , 0.01075505),
#        (0.0026319 , 0.00814774), (0.00262338, 0.00716903),
#        (0.00261806, 0.00828084), (0.00259654, 0.01329442),
#        (0.00257564, 0.00738658), (0.00252875, 0.00739359),
#        (0.00252081, 0.00585898), (0.00251093, 0.00762133),
#        (0.00247577, 0.01626129), (0.00246685, 0.00935512),
#        (0.00246422, 0.01428745), (0.00240327, 0.01292718),
#        (0.00238766, 0.00834844), (0.00237329, 0.01076942),
#        (0.00230443, 0.00624866), (0.00222262, 0.01042433),
#        (0.00219171, 0.00654501), (0.00213581, 0.0097742 ),
#        (0.00210886, 0.01109531), (0.00207479, 0.00621833),
#        (0.0020667 , 0.01672104), (0.00203671, 0.00537716),
#        (0.00189332, 0.00552377), (0.00187865, 0.00448079),
#        (0.00182035, 0.00861353), (0.00181325, 0.00395718),
#        (0.00176782, 0.00534127), (0.00170271, 0.00338663),
#        (0.00169402, 0.00358448), (0.00168667, 0.00390911),
#        (0.00156153, 0.00553993), (0.00154936, 0.00737648),
#        (0.00152607, 0.01143722), (0.00138643, 0.00730289),
#        (0.00135098, 0.00478523), (0.00134385, 0.00339212),
#        (0.00133448, 0.01199356), (0.00133193, 0.00491333),
#        (0.00129191, 0.0088256 ), (0.00123095, 0.0035403 ),
#        (0.00116078, 0.00437169), (0.00106218, 0.01230205),
#        (0.00088986, 0.00374733), (0.00082222, 0.00283846),
#        (0.00075006, 0.00356912), (0.00073259, 0.00703031)],
#       dtype=[('birth', '<f4'), ('death', '<f4')])}, 'pairs': {0: [[array([238]), array([494, 238])], [array([227]), array([483, 227])], [array([142]), array([398, 142])], [array([59]), array([315,  59])], [array([242]), array([498, 242])], [array([205]), array([461, 205])], [array([135]), array([391, 135])], [array([130]), array([386, 130])], [array([112]), array([368, 112])], [array([108]), array([364, 108])], [array([101]), array([357, 101])], [array([76]
])], [array([216]), array([472, 216])], [array([210]), array([466, 210])], [array([198]), array([454, 198])], [array([188]), array([444, 188])], [array([184]), array([440, 184])], [array([173]), array([429, 173])], [array([169]), array([425, 169])], [array([165]), array([421, 165])], [array([154]), array([410, 154])], [array([150]), array([406, 150])], [array([139]), array([395, 139])], [array([133]), array([389, 133])], [array([130]), array([386, 130])], [array([120]), array([376, 120])], [array([108]), array([364, 108])], [array([103]), array([359, 103])], [array([92]), array([348,  92])], [array([62]), array([318,  62])], [array([60]), array([316,  60])], [array([55]), array([311,  55])], [array([45]), array([301,  45])], [array([43]), array([299,  43])], [array([34]), array([290,  34])], [array([28]), array([284,  28])], [array([9]), array([265,   9])], [array([229]), array([485, 229])], [array([211]), array([467, 211])], [array([199]), array([455, 199])], [array([186]), array([442, 186])], [array([177]), array([433, 177])], [array([158]), array([414, 158])], [array([156]), array([412, 156])], [array([153]), array([409, 153])], [array([126]), array([382, 126])], [array([115]), array([371, 115])], [array([96]), array([352,  96])], [array([61]), array([317,  61])], [array([56]), array([312,  56])], [array([32]), array([288,  32])], [array([10]), array([266,  10])], [array([64]), array([320,  64])], [array([2]), array([258,   2])], [array([159]), array([415, 159])]], 1: []}}
# {'dgms': {0: array([(0., 1.5258789e-05), (0., 2.1579186e-05), (0., 3.0517578e-05),
#        (0., 3.7376249e-05), (0., 5.2857995e-05), (0., 5.2857995e-05),
#        (0., 6.1035156e-05), (0., 7.4752497e-05)],
#       dtype=[('birth', '<f4'), ('death', '<f4')]), 1: array([(0.02961872, 0.03282432), (0.02053954, 0.02328645)],
#       dtype=[('birth', '<f4'), ('death', '<f4')])}, 'pairs': {0: [[array([4]), array([36,  4])], [array([5]), array([37,  5])], [array([13]), array([45, 13])], [array([12]), array([44, 12])], [array([25]), array([57, 25])], [array([1]), array([33,  1])], [array([31]), array([63, 31])], [array([30]), array([62, 30])]], 1: [[array([56, 59]), array([24, 27, 59])], [array([36, 61]), array([ 4, 29, 61])]]}}
# {'dgms': {0: array([(0., 4.3304812e-05), (0., 4.3304812e-05), (0., 8.6609623e-05),
#        (0., 8.6609623e-05), (0., 8.6609623e-05), (0., 1.2248449e-04),
#        (0., 1.2248449e-04), (0., 1.2248449e-04)],
#       dtype=[('birth', '<f4'), ('death', '<f4')]), 1: array([(0.049939  , 0.05070252), (0.04965859, 0.05070252),
#        (0.04946976, 0.0499854 ), (0.04732341, 0.12186546),
#        (0.04688761, 0.10092954), (0.04374535, 0.08863571),
#        (0.04363928, 0.04403404), (0.04342364, 0.1004719 ),
#        (0.04239111, 0.04791039), (0.04232175, 0.09352039),
#        (0.04199162, 0.0804202 ), (0.04171816, 0.07938482),
#        (0.04120979, 0.04321816), (0.04092675, 0.06514926),
#        (0.04063584, 0.09490065), (0.04001794, 0.078412  ),
#        (0.03989361, 0.05845633), (0.03976627, 0.08727169),
#        (0.03827182, 0.08683955), (0.03787122, 0.05538115),
#        (0.03771911, 0.05801249), (0.03724955, 0.06529585),
#        (0.03635186, 0.03705659), (0.03591115, 0.10285324),
#        (0.03584668, 0.05848649), (0.0352573 , 0.04825126),
#        (0.03494041, 0.06089913), (0.03391667, 0.08526844),
#        (0.03162859, 0.05920368), (0.03092914, 0.04248412),
#        (0.02987362, 0.05091906), (0.02727436, 0.04543028),
#        (0.02595811, 0.03502572), (0.018091  , 0.0265239 ),
#        (0.01791678, 0.04049109)],
#       dtype=[('birth', '<f4'), ('death', '<f4')])}, 'pairs': {0: [[array([22]), array([54, 22])], [array([4]), array([36,  4])], [array([15]), array([47, 15])], [array([11]), array([43, 11])], [array([1]), array([33,  1])], [array([28]), array([60, 28])], [array([26]), array([58, 26])], [array([13]), array([45, 13])]], 1: [[array([53, 62]), array([40, 47, 62])], [array([41, 62]), array([40, 41, 62])], [array([52, 56]), array([33, 40, 52])], [array([33, 61]), array([ 1, 29, 44])], [array([33, 52]), array([ 1, 20, 52])], [array([35, 61]), array([21, 30, 62])], [array([44, 46]), array([39, 44, 46])], [array([47, 62]), array([ 3, 29, 61])], [array([53, 59]), array([21, 26, 58])], [array([38, 40]), array([ 6, 27, 40])], [array([46, 50]), array([14, 25, 50])], [array([44, 57]), array([ 7, 12, 44])], [array([40, 41]), array([40, 41, 63])], [array([40, 56]), array([ 8, 27, 59])], [array([47, 61]), array([15, 29, 51])], [array([46, 63]), array([ 0, 14, 42])], [array([49, 51]), array([17, 19, 51])], [array([32, 48]), array([ 9, 27, 45])], [array([50, 60]), array([ 7, 28, 60])], [array([35, 46]), array([ 3, 14, 42])], [array([36, 37]), array([ 5, 22, 54])], [array([50, 57]), array([18, 25, 57])], [array([36, 49]), array([43, 55, 61])], [array([41, 48]), array([ 3, 16, 48])], [array([34, 36]), array([ 4, 22, 54])], [array([43, 61]), array([ 4, 17, 49])], [array([49, 55]), array([17, 23, 55])], [array([40, 46]), array([ 8, 18, 46])], [array([40, 45]), array([ 8, 26, 45])], [array([43, 55]), array([11, 23, 55])], [array([39, 50]), array([ 7, 18, 50])], [array([32, 63]), array([ 0, 31, 63])], [array([34, 54]), array([ 2, 22, 54])], [array([45, 58]), array([13, 26, 58])], [array([42, 46]), array([10, 14, 46])]]}}
# `Trainer.fit` stopped: `max_epochs=2` reached.

# %%
version = config['version']
train_loader = DataLoader(
    train,
    batch_size=config["batch_size"],
    num_workers=2,
    collate_fn=collate_with_matrix_geodesic if geodesic else collate_with_matrix,
    shuffle=False
)

for model_name in trained_models:
    latent, labels = get_latent_representations(trained_models[model_name], train_loader)
    np.save(f'data/{dataset_name}/{model_name}_output_{version}.npy', latent)
    np.save(f'data/{dataset_name}/{model_name}_labels_{version}.npy', labels)

# %%
test_loader = DataLoader(
    test, 
    batch_size=config["batch_size"], 
    num_workers=2, 
    collate_fn=collate_with_matrix_geodesic if geodesic else collate_with_matrix, 
    shuffle=False
)

# %%
for model_name in trained_models:
    latent, labels = get_latent_representations(trained_models[model_name], test_loader)
    np.save(f'data/{dataset_name}/{model_name}_output_{version}_test.npy', latent)
    np.save(f'data/{dataset_name}/{model_name}_labels_{version}_test.npy', labels)
